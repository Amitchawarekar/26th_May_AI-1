# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_excel('Data_Train.xlsx')
train_df.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# train_df.groupby(["Additional_Info"]).describe().T

# %%
test_df = pd.read_excel('Test_set.xlsx')
test_df.head(5)
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %% [markdown]
# ### Study the training data

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
train_df.groupby(["Additional_Info"]).describe().T
# Out:
# Additional_Info  1 Long layover  1 Short layover  2 Long layover  \
# Price count           19.000000              1.0             1.0
#       mean         22109.631579          26743.0         26480.0
#       std           8040.051155              NaN             NaN
#       min           7744.000000          26743.0         26480.0
#       25%          14673.000000          26743.0         26480.0
#       50%          25735.000000          26743.0         26480.0
#       75%          27992.000000          26743.0         26480.0
#       max          31825.000000          26743.0         26480.0
#
# Additional_Info  Business class  Change airports  In-flight meal not included  \
# Price count            4.000000         7.000000                  1982.000000
#       mean         56811.250000     16800.714286                  9471.834511
#       std          21381.667044      4449.728371                  2812.043362
#       min          28097.000000     13366.000000                  1840.000000
#       25%          49931.000000     13940.500000                  7757.000000
#       50%          59818.000000     15119.000000                 10262.000000
#       75%          66698.250000     17573.500000                 10844.000000
#       max          79512.000000     26092.000000                 19644.000000
#
# Additional_Info      No Info  No check-in baggage included       No info  \
# Price count         3.000000                    320.000000   8345.000000
#       mean       8044.666667                   3645.156250   9141.320192
#       std         119.181934                    865.712619   4714.100152
#       min        7917.000000                   1965.000000   1759.000000
#       25%        7990.500000                   3543.000000   5224.000000
#       50%        8064.000000                   3841.000000   8016.000000
#       75%        8108.500000                   3859.000000  12970.000000
#       max        8153.000000                   6356.000000  54826.000000
#
# Additional_Info  Red-eye flight
# Price count                 1.0
#       mean              10873.0
#       std                   NaN
#       min               10873.0
#       25%               10873.0
#       50%               10873.0
#       75%               10873.0
#       max               10873.0

# %%
train_df.groupby('Airline').describe().T
# Out:
# Airline          Air Asia     Air India         GoAir        IndiGo  \
# Price count    319.000000   1752.000000    194.000000   2053.000000
#       mean    5590.260188   9611.210616   5861.056701   5673.682903
#       std     2027.362290   3900.952942   2703.585767   2264.142168
#       min     3383.000000   2050.000000   3398.000000   2227.000000
#       25%     4282.000000   6896.000000   3898.000000   4226.000000
#       50%     5162.000000   9443.000000   5135.000000   5000.000000
#       75%     6451.000000  12219.000000   6811.250000   6494.000000
#       max    13774.000000  31945.000000  22794.000000  22153.000000
#
# Airline       Jet Airways  Jet Airways Business  Multiple carriers  \
# Price count   3849.000000              6.000000        1196.000000
#       mean   11643.923357          58358.666667       10902.678094
#       std     4258.940578          11667.596748        3721.234997
#       min     1840.000000          46490.000000        5797.000000
#       25%     9134.000000          52243.000000        7723.000000
#       50%    11467.000000          54747.000000       10197.000000
#       75%    14151.000000          61122.500000       13587.000000
#       max    54826.000000          79512.000000       36983.000000
#
# Airline      Multiple carriers Premium economy      SpiceJet  Trujet  \
# Price count                          13.000000    818.000000     1.0
#       mean                        11418.846154   4338.284841  4140.0
#       std                          1717.153936   1849.922514     NaN
#       min                          9845.000000   1759.000000  4140.0
#       25%                         10161.000000   3574.500000  4140.0
#       50%                         11269.000000   3873.000000  4140.0
#       75%                         11269.000000   4760.000000  4140.0
#       max                         14629.000000  23267.000000  4140.0
#
# Airline           Vistara  Vistara Premium economy
# Price count    479.000000                 3.000000
#       mean    7796.348643              8962.333333
#       std     2914.298578              2915.405518
#       min     3687.000000              5969.000000
#       25%     5403.000000              7547.000000
#       50%     7980.000000              9125.000000
#       75%     9345.000000             10459.000000
#       max    21730.000000             11793.000000

# %%
train_df.groupby(['Source','Destination','Airline']).describe()
# Out:
#                                                          Price                \
#                                                          count          mean
# Source   Destination Airline
# Banglore Delhi       Air Asia                             71.0   4265.577465
#                      Air India                           120.0   6045.166667
#                      GoAir                                69.0   4050.289855
#                      IndiGo                              366.0   4399.581967
#                      Jet Airways                         370.0   6412.954054
#                      SpiceJet                            137.0   4012.839416
#                      Vistara                             131.0   5042.312977
#                      Vistara Premium economy               1.0   5969.000000
#          New Delhi   Air Asia                             18.0   5791.944444
#                      Air India                           212.0  11045.575472
#                      GoAir                                24.0   7532.333333
#                      IndiGo                              157.0   7312.828025
#                      Jet Airways                         418.0  15101.272727
#                      Jet Airways Business                  4.0  62844.250000
#                      SpiceJet                             44.0   6223.727273
#                      Vistara                              54.0   8947.388889
#                      Vistara Premium economy               1.0  11793.000000
# Chennai  Kolkata     Air India                            25.0   5895.640000
#                      IndiGo                              184.0   4538.766304
#                      SpiceJet                            128.0   3993.523438
#                      Vistara                              43.0   7491.372093
#                      Vistara Premium economy               1.0   9125.000000
# Delhi    Cochin      Air Asia                             80.0   7804.175000
#                      Air India                           747.0  10000.068273
#                      GoAir                                76.0   6587.157895
#                      IndiGo                              705.0   7203.933333
#                      Jet Airways                        1586.0  12642.593317
#                      Jet Airways Business                  2.0  49387.500000
#                      Multiple carriers                  1196.0  10902.678094
#                      Multiple carriers Premium economy    13.0  11418.846154
#                      SpiceJet                             87.0   5916.356322
#                      Vistara                              45.0   6465.644444
# Kolkata  Banglore    Air Asia                            150.0   5012.320000
#                      Air India                           512.0  10357.324219
#                      GoAir                                25.0   7047.000000
#                      IndiGo                              445.0   5075.235955
#                      Jet Airways                        1256.0  11717.565287
#                      SpiceJet                            300.0   4642.883333
#                      Vistara                             183.0   9257.683060
# Mumbai   Hyderabad   Air India                           136.0   6260.051471
#                      IndiGo                              196.0   3659.816327
#                      Jet Airways                         219.0   6227.949772
#                      SpiceJet                            122.0   2511.106557
#                      Trujet                                1.0   4140.000000
#                      Vistara                              23.0  12326.521739
#
#                                                                                \
#                                                                  std      min
# Source   Destination Airline
# Banglore Delhi       Air Asia                            1096.443102   3383.0
#                      Air India                            854.037699   4441.0
#                      GoAir                                693.551815   3398.0
#                      IndiGo                               517.835450   3359.0
#                      Jet Airways                         1397.652676   3359.0
#                      SpiceJet                             535.910663   3257.0
#                      Vistara                              387.680362   4668.0
#                      Vistara Premium economy                     NaN   5969.0
#          New Delhi   Air Asia                            2283.509695   3383.0
#                      Air India                           4758.084150   3758.0
#                      GoAir                               3449.644653   3898.0
#                      IndiGo                              2691.638009   3897.0
#                      Jet Airways                         7256.612618   5853.0
#                      Jet Airways Business               11866.304715  52229.0
#                      SpiceJet                            3240.862922   3527.0
#                      Vistara                             4256.913579   4353.0
#                      Vistara Premium economy                     NaN  11793.0
# Chennai  Kolkata     Air India                           3358.822783   3145.0
#                      IndiGo                              1265.102974   3384.0
#                      SpiceJet                            1080.082389   3332.0
#                      Vistara                             3949.448617   3687.0
#                      Vistara Premium economy                     NaN   9125.0
# Delhi    Cochin      Air Asia                            2049.075072   6151.0
#                      Air India                           3189.265128   4487.0
#                      GoAir                               2886.375254   3876.0
#                      IndiGo                              2263.063984   4729.0
#                      Jet Airways                         2891.275512   4256.0
#                      Jet Airways Business                4097.683797  46490.0
#                      Multiple carriers                   3721.234997   5797.0
#                      Multiple carriers Premium economy   1717.153936   9845.0
#                      SpiceJet                            1423.907627   4098.0
#                      Vistara                             1072.668850   4851.0
# Kolkata  Banglore    Air Asia                            1255.883156   3782.0
#                      Air India                           3436.946641   4145.0
#                      GoAir                               2150.129860   3514.0
#                      IndiGo                              1242.438414   3480.0
#                      Jet Airways                         2322.481782   5608.0
#                      SpiceJet                            1634.281417   3815.0
#                      Vistara                             1410.273626   7770.0
# Mumbai   Hyderabad   Air India                           5202.955707   2050.0
#                      IndiGo                              2086.915780   2227.0
#                      Jet Airways                         4264.992926   1840.0
#                      SpiceJet                            1691.497512   1759.0
#                      Trujet                                      NaN   4140.0
#                      Vistara                              132.848468  12080.0
#
#                                                                            \
#                                                              25%      50%
# Source   Destination Airline
# Banglore Delhi       Air Asia                            3383.00   4282.0
#                      Air India                           5228.00   6121.0
#                      GoAir                               3419.00   3898.0
#                      IndiGo                              3943.00   4423.0
#                      Jet Airways                         5198.00   7229.0
#                      SpiceJet                            3625.00   3971.0
#                      Vistara                             4668.00   4878.0
#                      Vistara Premium economy             5969.00   5969.0
#          New Delhi   Air Asia                            4284.00   5048.5
#                      Air India                           7591.00  11003.0
#                      GoAir                               5541.50   7222.0
#                      IndiGo                              5694.00   6860.0
#                      Jet Airways                        11000.75  13555.0
#                      Jet Airways Business               55964.00  59818.0
#                      SpiceJet                            4273.00   5575.0
#                      Vistara                             6083.25   7608.0
#                      Vistara Premium economy            11793.00  11793.0
# Chennai  Kolkata     Air India                           4667.00   4667.0
#                      IndiGo                              3597.00   3854.0
#                      SpiceJet                            3543.00   3597.0
#                      Vistara                             3687.00   5944.0
#                      Vistara Premium economy             9125.00   9125.0
# Delhi    Cochin      Air Asia                            6227.75   6752.0
#                      Air India                           7690.00   9719.0
#                      GoAir                               5135.00   5842.0
#                      IndiGo                              6093.00   6494.0
#                      Jet Airways                        10262.00  12898.0
#                      Jet Airways Business               47938.75  49387.5
#                      Multiple carriers                   7723.00  10197.0
#                      Multiple carriers Premium economy  10161.00  11269.0
#                      SpiceJet                            5034.00   5583.0
#                      Vistara                             6216.00   6216.0
# Kolkata  Banglore    Air Asia                            4384.00   4409.0
#                      Air India                           7852.75  10676.0
#                      GoAir                               6095.00   7102.0
#                      IndiGo                              4226.00   4804.0
#                      Jet Airways                         9899.00  11467.0
#                      SpiceJet                            3841.00   3873.0
#                      Vistara                             8452.00   8820.0
# Mumbai   Hyderabad   Air India                           3100.00   3100.0
#                      IndiGo                              2754.00   3175.0
#                      Jet Airways                         4050.00   5678.0
#                      SpiceJet                            1965.00   2017.0
#                      Trujet                              4140.00   4140.0
#                      Vistara                            12395.00  12395.0
#
#
#                                                              75%      max
# Source   Destination Airline
# Banglore Delhi       Air Asia                            4483.00   8420.0
#                      Air India                           6961.00   8273.0
#                      GoAir                               4239.00   6722.0
#                      IndiGo                              4823.00   6906.0
#                      Jet Airways                         7229.00   8541.0
#                      SpiceJet                            4319.00   5621.0
#                      Vistara                             5403.00   5823.0
#                      Vistara Premium economy             5969.00   5969.0
#          New Delhi   Air Asia                            6924.75  10873.0
#                      Air India                          12793.75  31783.0
#                      GoAir                               7830.75  18558.0
#                      IndiGo                              8033.00  22153.0
#                      Jet Airways                        17261.00  54826.0
#                      Jet Airways Business               66698.25  79512.0
#                      SpiceJet                            6860.00  23267.0
#                      Vistara                            11598.00  21730.0
#                      Vistara Premium economy            11793.00  11793.0
# Chennai  Kolkata     Air India                           4667.00  19630.0
#                      IndiGo                              5277.00   8580.0
#                      SpiceJet                            3649.50   7718.0
#                      Vistara                            11982.00  11982.0
#                      Vistara Premium economy             9125.00   9125.0
# Delhi    Cochin      Air Asia                            8759.00  13774.0
#                      Air India                          11926.50  28322.0
#                      GoAir                               6989.75  22794.0
#                      IndiGo                              7255.00  16162.0
#                      Jet Airways                        14714.00  21954.0
#                      Jet Airways Business               50836.25  52285.0
#                      Multiple carriers                  13587.00  36983.0
#                      Multiple carriers Premium economy  11269.00  14629.0
#                      SpiceJet                            6181.00  11726.0
#                      Vistara                             6741.00  12411.0
# Kolkata  Banglore    Air Asia                            5192.00  11323.0
#                      Air India                          12798.25  31945.0
#                      GoAir                               8855.00  10586.0
#                      IndiGo                              5224.00  12198.0
#                      Jet Airways                        13941.00  15149.0
#                      SpiceJet                            4523.75  12287.0
#                      Vistara                             9345.00  16932.0
# Mumbai   Hyderabad   Air India                           9796.25  25139.0
#                      IndiGo                              4049.00  17501.0
#                      Jet Airways                         5678.00  24210.0
#                      SpiceJet                            2385.00  13552.0
#                      Trujet                              4140.00   4140.0
#                      Vistara                            12395.00  12395.0

# %%
train_df.groupby(['Source','Destination','Date_of_Journey']).describe().head(10)
# Out:
#                                      Price                                    \
#                                      count         mean          std     min
# Source   Destination Date_of_Journey
# Banglore Delhi       1/04/2019        40.0  5038.700000  1158.628106  3573.0
#                      1/05/2019        42.0  5040.666667  1156.266862  3898.0
#                      1/06/2019        47.0  5475.319149  1588.356001  3419.0
#                      12/04/2019       42.0  5576.714286   959.676452  4282.0
#                      12/05/2019       48.0  4991.145833  1203.464237  3257.0
#                      12/06/2019       44.0  5255.727273  1467.850879  3383.0
#                      15/04/2019       41.0  5109.341463  1031.326054  3898.0
#                      15/05/2019       46.0  4718.913043  1341.389592  3257.0
#                      15/06/2019       39.0  5520.435897  1647.407897  3383.0
#                      18/04/2019       40.0  5447.675000   964.843614  4282.0
#
#
#                                           25%     50%      75%     max
# Source   Destination Date_of_Journey
# Banglore Delhi       1/04/2019        4239.00  4567.5  5403.00  7229.0
#                      1/05/2019        4128.25  4668.0  5890.25  7229.0
#                      1/06/2019        3957.00  4823.0  7229.00  8016.0
#                      12/04/2019       4898.00  5300.5  5911.00  7229.0
#                      12/05/2019       4219.00  4668.0  5280.50  7229.0
#                      12/06/2019       4225.00  4823.0  5769.00  8016.0
#                      15/04/2019       4423.00  4823.0  5403.00  7229.0
#                      15/05/2019       3704.50  4300.5  5118.00  7229.0
#                      15/06/2019       3957.00  4878.0  7229.00  8016.0
#                      18/04/2019       4591.00  5213.0  5790.75  7229.0

# %%
train_df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_df.dropna(inplace=True)

# %%
train_df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
print('Airline',train_df['Airline'].unique())
print('Total Stops',train_df['Total_Stops'].unique())
# Out:
# Airline ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
# Total Stops ['non-stop' '2 stops' '1 stop' '3 stops' '4 stops']

# %% [markdown]
# ### Study the test data

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %%
test_df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
train_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
train_df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
train_df.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %%
train_df.apply(lambda x:x.unique())
# Out:
# Airline            [IndiGo, Air India, Jet Airways, SpiceJet, Mul...
# Date_of_Journey    [24/03/2019, 1/05/2019, 9/06/2019, 12/05/2019,...
# Source                   [Banglore, Kolkata, Delhi, Chennai, Mumbai]
# Destination        [New Delhi, Banglore, Cochin, Kolkata, Delhi, ...
# Route              [BLR → DEL, CCU → IXR → BBI → BLR, DEL → LKO →...
# Dep_Time           [22:20, 05:50, 09:25, 18:05, 16:50, 09:00, 18:...
# Arrival_Time       [01:10 22 Mar, 13:15, 04:25 10 Jun, 23:30, 21:...
# Duration           [2h 50m, 7h 25m, 19h, 5h 25m, 4h 45m, 2h 25m, ...
# Total_Stops            [non-stop, 2 stops, 1 stop, 3 stops, 4 stops]
# Additional_Info    [No info, In-flight meal not included, No chec...
# Price              [3897, 7662, 13882, 6218, 13302, 3873, 11087, ...
# dtype: object

# %%
train_df[train_df['Total_Stops'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %%
train_df['Arrival_Time'] = train_df['Arrival_Time'].apply(lambda x:x.split(' ')[0])
train_df['Total_Stops'] = train_df['Total_Stops'].replace('non-stop','0 stop') 
train_df['Total_Stops'] = train_df['Total_Stops'].fillna('1 stop')

# %%
#Date of journey is of dtype Object so preprocessing it.

train_df['Date'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')[0])
train_df['Month'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')[1]) 
train_df['Year'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')[2])
train_df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897   24
# 1    05:50        13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25        04:25      19h     2 stops         No info  13882    9
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019

# %%
train_df['Dep_hour'] = train_df['Dep_Time'].apply(lambda x:x.split(':')[0])
train_df['Dep_minute'] = train_df['Dep_Time'].apply(lambda x:x.split(':')[1])
train_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897   24
# 1    05:50        13:15   7h 25m     2 stops         No info   7662    1
#
#   Month  Year Dep_hour Dep_minute
# 0    03  2019       22         20
# 1    05  2019       05         50

# %%
train_df['Arrival_hour'] = train_df['Arrival_Time'].apply(lambda x:x.split(':')[0])
train_df['Arrival_minute'] = train_df['Arrival_Time'].apply(lambda x:x.split(':')[1])
train_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897   24
# 1    05:50        13:15   7h 25m     2 stops         No info   7662    1
#
#   Month  Year Dep_hour Dep_minute Arrival_hour Arrival_minute
# 0    03  2019       22         20           01             10
# 1    05  2019       05         50           13             15

# %%
train_df['Total_Stops'] = train_df['Total_Stops'].apply(lambda x:x.split(' ')[0])
train_df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    22:20        01:10   2h 50m           0         No info   3897   24
# 1    05:50        13:15   7h 25m           2         No info   7662    1
# 2    09:25        04:25      19h           2         No info  13882    9
#
#   Month  Year Dep_hour Dep_minute Arrival_hour Arrival_minute
# 0    03  2019       22         20           01             10
# 1    05  2019       05         50           13             15
# 2    06  2019       09         25           04             25

# %%
train_df.drop(['Date_of_Journey','Dep_Time','Arrival_Time'],axis=1,inplace=True)

# %%
train_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info  Price Date Month  Year Dep_hour Dep_minute  \
# 0           0         No info   3897   24    03  2019       22         20
# 1           2         No info   7662    1    05  2019       05         50
#
#   Arrival_hour Arrival_minute
# 0           01             10
# 1           13             15

# %%
train_df.groupby(['Route']).describe().T
max(train_df['Total_Stops'])
# Out:
# '4'

# %%
train_df['Route_1'] = pd.Series(train_df['Route'].str.split('→ ')[0])
train_df['Route_2'] = pd.Series(train_df['Route'].str.split('→ ')[1])
train_df['Route_3'] = pd.Series(train_df['Route'].str.split('→ ')[2])
train_df['Route_4'] = pd.Series(train_df['Route'].str.split('→ ')[3])
train_df['Route_5'] = pd.Series(train_df['Route'].str.split('→ ')[4])
train_df.drop('Route',axis=1,inplace=True)
train_df.head(2)
# Out:
#      Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0     IndiGo  Banglore   New Delhi   2h 50m           0         No info
# 1  Air India   Kolkata    Banglore   7h 25m           2         No info
#
#    Price Date Month  Year Dep_hour Dep_minute Arrival_hour Arrival_minute  \
# 0   3897   24    03  2019       22         20           01             10
# 1   7662    1    05  2019       05         50           13             15
#
#   Route_1 Route_2 Route_3 Route_4 Route_5
# 0    BLR     CCU     DEL     CCU     BLR
# 1     DEL    IXR     LKO     NAG     NAG

# %%
train_df['Route_1'].fillna('None',inplace=True)
train_df['Route_2'].fillna('None',inplace=True)
train_df['Route_3'].fillna('None',inplace=True)
train_df['Route_4'].fillna('None',inplace=True)
train_df['Route_5'].fillna('None',inplace=True)

# %%
train_df.drop('Duration',axis=1,inplace=True)

# %%
train_df.head(2)
# Out:
#      Airline    Source Destination Total_Stops Additional_Info  Price Date  \
# 0     IndiGo  Banglore   New Delhi           0         No info   3897   24
# 1  Air India   Kolkata    Banglore           2         No info   7662    1
#
#   Month  Year Dep_hour Dep_minute Arrival_hour Arrival_minute Route_1 Route_2  \
# 0    03  2019       22         20           01             10    BLR     CCU
# 1    05  2019       05         50           13             15     DEL    IXR
#
#   Route_3 Route_4 Route_5
# 0    DEL     CCU     BLR
# 1    LKO     NAG     NAG

# %%
print("Airline",train_df['Airline'].unique(),train_df['Airline'].nunique())
print("Source",train_df['Source'].unique())
print("Destination",train_df['Destination'].unique())
print("Total_Stops",train_df['Total_Stops'].unique())
print("Additional_Info",train_df['Additional_Info'].unique())
# Out:
# Airline ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet'] 12
# Source ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# Destination ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']
# Total_Stops ['0' '2' '1' '3' '4']
# Additional_Info ['No info' 'In-flight meal not included' 'No check-in baggage included'
#  '1 Short layover' 'No Info' '1 Long layover' 'Change airports'
#  'Business class' 'Red-eye flight' '2 Long layover']

# %%
train_df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date               object
# Month              object
# Year               object
# Dep_hour           object
# Dep_minute         object
# Arrival_hour       object
# Arrival_minute     object
# Route_1            object
# Route_2            object
# Route_3            object
# Route_4            object
# Route_5            object
# dtype: object

# %%
train_df['Date'] = train_df['Date'].astype('int64')
train_df['Month'] = train_df['Month'].astype('int64')
train_df['Year'] = train_df['Year'].astype('int64')
train_df['Dep_hour'] = train_df['Dep_hour'].astype('int64')
train_df['Dep_minute'] = train_df['Dep_minute'].astype('int64')
train_df['Arrival_hour'] = train_df['Arrival_hour'].astype('int64')
train_df['Arrival_minute'] = train_df['Arrival_minute'].astype('int64')
train_df['Total_Stops'] = train_df['Total_Stops'].astype('int64')

# %%
# Converting Categorical data into Numeric Data

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()


train_df['Airline'] = encoder.fit_transform(train_df['Airline'])
train_df['Source'] = encoder.fit_transform(train_df['Source'])
train_df['Destination'] = encoder.fit_transform(train_df['Destination'])
train_df['Additional_Info'] = encoder.fit_transform(train_df['Additional_Info'])
train_df['Route_1'] = encoder.fit_transform(train_df['Route_1'])
train_df['Route_2'] = encoder.fit_transform(train_df['Route_2'])
train_df['Route_3'] = encoder.fit_transform(train_df['Route_3'])
train_df['Route_4'] = encoder.fit_transform(train_df['Route_4'])
train_df['Route_5'] = encoder.fit_transform(train_df['Route_5'])

train_df.head(5)
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0        3       0            5            0                8   3897    24
# 1        1       3            0            2                8   7662     1
# 2        4       2            1            2                8  13882     9
# 3        3       3            0            1                8   6218    12
# 4        3       0            5            1                8  13302     1
#
#    Month  Year  Dep_hour  Dep_minute  Arrival_hour  Arrival_minute  Route_1  \
# 0      3  2019        22          20             1              10        0
# 1      5  2019         5          50            13              15        1
# 2      6  2019         9          25             4              25        2
# 3      5  2019        18           5            23              30        2
# 4      3  2019        16          50            21              35        2
#
#    Route_2  Route_3  Route_4  Route_5
# 0        2        2        1        0
# 1        3        3        2        2
# 2        0        0        0        1
# 3        1        1        3        3
# 4        4        4        3        3

# %%
train_df.dtypes
# Out:
# Airline            int32
# Source             int32
# Destination        int32
# Total_Stops        int64
# Additional_Info    int32
# Price              int64
# Date               int64
# Month              int64
# Year               int64
# Dep_hour           int64
# Dep_minute         int64
# Arrival_hour       int64
# Arrival_minute     int64
# Route_1            int32
# Route_2            int32
# Route_3            int32
# Route_4            int32
# Route_5            int32
# dtype: object

# %%
train_df.hist(figsize=(25,15))
# Out:
# array([[<AxesSubplot:title={'center':'Airline'}>,
#         <AxesSubplot:title={'center':'Source'}>,
#         <AxesSubplot:title={'center':'Destination'}>,
#         <AxesSubplot:title={'center':'Total_Stops'}>],
#        [<AxesSubplot:title={'center':'Additional_Info'}>,
#         <AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Month'}>],
#        [<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Dep_hour'}>,
#         <AxesSubplot:title={'center':'Dep_minute'}>,
#         <AxesSubplot:title={'center':'Arrival_hour'}>],
#        [<AxesSubplot:title={'center':'Arrival_minute'}>,
#         <AxesSubplot:title={'center':'Route_1'}>,
#         <AxesSubplot:title={'center':'Route_2'}>,
#         <AxesSubplot:title={'center':'Route_3'}>],
#        [<AxesSubplot:title={'center':'Route_4'}>,
#         <AxesSubplot:title={'center':'Route_5'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.scatter(train_df['Airline'],train_df['Price'])

# %%
import seaborn as sns

# %% [markdown]
# ### Model Implementation

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = train_df.drop('Price',axis=1)
y= train_df['Price']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size =0.25,random_state=101)

# %%
linearReg = LinearRegression()
logisticReg = LogisticRegression()

# %%
linear_model = linearReg.fit(xtrain,ytrain)

# %%
logistic_model = logisticReg.fit(xtrain,ytrain)

# %%
linear_model.score(xtest,ytest)  # very less score
# Out:
# 0.42848817127346595

# %%
logistic_model.score(xtest,ytest) #very less score
# Out:
# 0.04380381879445901

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix

# %%
decision_tree = DecisionTreeRegressor()
random_forest =  RandomForestRegressor()

# %%
Dtree_model = decision_tree.fit(xtrain,ytrain)

# %%
Dtree_model.score(xtest,ytest)
# Out:
# 0.841701024715413

# %%
Rforest_model = random_forest.fit(xtrain,ytrain)

# %%
Rforest_model.score(xtest,ytest)
# Out:
# 0.903379016500118

# %%
Dtree_model.criterion
# Out:
# 'mse'

# %%
Dtree_model.decision_path(xtrain)
# Out:
# <8011x8441 sparse matrix of type '<class 'numpy.int64'>'
# 	with 127102 stored elements in Compressed Sparse Row format>

# %%
imp_Dtree_model= pd.DataFrame(Dtree_model.feature_importances_*100,index=X.columns,columns=['Feature Importance'])

# %%
imp_Dtree_model
# Out:
#                  Feature Importance
# Airline                   17.835755
# Source                     1.600581
# Destination                3.117582
# Total_Stops               43.269679
# Additional_Info            8.344539
# Date                       9.262292
# Month                      4.574888
# Year                       0.000000
# Dep_hour                   3.048081
# Dep_minute                 3.857207
# Arrival_hour               3.312373
# Arrival_minute             1.766931
# Route_1                    0.000000
# Route_2                    0.009093
# Route_3                    0.000000
# Route_4                    0.001000
# Route_5                    0.000000

# %%
X2 = train_df.drop(['Year','Route_1','Route_2','Route_3','Route_4','Route_5','Price'],axis=1)
y2 = train_df['Price']
xtrain2,xtest2,ytrain2,ytest2 = train_test_split(X2,y2,test_size =0.25,random_state=101)
Dtree_model2 = decision_tree.fit(xtrain2,ytrain2)
Rforest_model2 = random_forest.fit(xtrain2,ytrain2)

# %%
round(Dtree_model2.score(xtest2,ytest2)*100,2)
# Out:
# 82.9

# %%
round(Rforest_model.score(xtest2,ytest2)*100,2)
# Out:
# 90.36

# %%
imp_Dtree_model2= pd.DataFrame(Dtree_model2.feature_importances_*100,index=X2.columns,columns=['Feature Importance'])
imp_Dtree_model2
# Out:
#                  Feature Importance
# Airline                   17.022397
# Source                     1.590051
# Destination                3.019605
# Total_Stops               43.282342
# Additional_Info            8.377563
# Date                       9.316461
# Month                      4.580270
# Dep_hour                   3.216026
# Dep_minute                 3.061575
# Arrival_hour               3.579547
# Arrival_minute             2.954162

# %%
Rforest_model2.estimator_params
# Out:
# ('criterion',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_features',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'random_state',
#  'ccp_alpha')

# %%
Rforest_model2.criterion
# Out:
# 'mse'

# %%
Rforest_model2.estimators_
# Out:
# [DecisionTreeRegressor(max_features='auto', random_state=1672228333),
#  DecisionTreeRegressor(max_features='auto', random_state=217664549),
#  DecisionTreeRegressor(max_features='auto', random_state=279890047),
#  DecisionTreeRegressor(max_features='auto', random_state=1626143942),
#  DecisionTreeRegressor(max_features='auto', random_state=1343952270),
#  DecisionTreeRegressor(max_features='auto', random_state=798522412),
#  DecisionTreeRegressor(max_features='auto', random_state=1665638097),
#  DecisionTreeRegressor(max_features='auto', random_state=162999199),
#  DecisionTreeRegressor(max_features='auto', random_state=796679812),
#  DecisionTreeRegressor(max_features='auto', random_state=1460921925),
#  DecisionTreeRegressor(max_features='auto', random_state=1265157739),
#  DecisionTreeRegressor(max_features='auto', random_state=439432905),
#  DecisionTreeRegressor(max_features='auto', random_state=796848303),
#  DecisionTreeRegressor(max_features='auto', random_state=1331411215),
#  DecisionTreeRegressor(max_features='auto', random_state=1123513157),
#  DecisionTreeRegressor(max_features='auto', random_state=454401595),
#  DecisionTreeRegressor(max_features='auto', random_state=652784047),
#  DecisionTreeRegressor(max_features='auto', random_state=207752270),
#  DecisionTreeRegressor(max_features='auto', random_state=1439061935),
#  DecisionTreeRegressor(max_features='auto', random_state=733463120),
#  DecisionTreeRegressor(max_features='auto', random_state=1932562227),
#  DecisionTreeRegressor(max_features='auto', random_state=1744443133),
#  DecisionTreeRegressor(max_features='auto', random_state=1383182556),
#  DecisionTreeRegressor(max_features='auto', random_state=1423534437),
#  DecisionTreeRegressor(max_features='auto', random_state=761130240),
#  DecisionTreeRegressor(max_features='auto', random_state=653527115),
#  DecisionTreeRegressor(max_features='auto', random_state=1502121726),
#  DecisionTreeRegressor(max_features='auto', random_state=1102729124),
#  DecisionTreeRegressor(max_features='auto', random_state=216009554),
#  DecisionTreeRegressor(max_features='auto', random_state=1845676357),
#  DecisionTreeRegressor(max_features='auto', random_state=1499168045),
#  DecisionTreeRegressor(max_features='auto', random_state=521558238),
#  DecisionTreeRegressor(max_features='auto', random_state=1419828682),
#  DecisionTreeRegressor(max_features='auto', random_state=46848609),
#  DecisionTreeRegressor(max_features='auto', random_state=1902010823),
#  DecisionTreeRegressor(max_features='auto', random_state=213826813),
#  DecisionTreeRegressor(max_features='auto', random_state=1797701472),
#  DecisionTreeRegressor(max_features='auto', random_state=8892951),
#  DecisionTreeRegressor(max_features='auto', random_state=1846077923),
#  DecisionTreeRegressor(max_features='auto', random_state=875709629),
#  DecisionTreeRegressor(max_features='auto', random_state=756316233),
#  DecisionTreeRegressor(max_features='auto', random_state=1260819278),
#  DecisionTreeRegressor(max_features='auto', random_state=723589606),
#  DecisionTreeRegressor(max_features='auto', random_state=79289199),
#  DecisionTreeRegressor(max_features='auto', random_state=1679950557),
#  DecisionTreeRegressor(max_features='auto', random_state=158214519),
#  DecisionTreeRegressor(max_features='auto', random_state=1471258706),
#  DecisionTreeRegressor(max_features='auto', random_state=38902663),
#  DecisionTreeRegressor(max_features='auto', random_state=561525361),
#  DecisionTreeRegressor(max_features='auto', random_state=1757097386),
#  DecisionTreeRegressor(max_features='auto', random_state=1013929310),
#  DecisionTreeRegressor(max_features='auto', random_state=207488298),
#  DecisionTreeRegressor(max_features='auto', random_state=58725746),
#  DecisionTreeRegressor(max_features='auto', random_state=52585198),
#  DecisionTreeRegressor(max_features='auto', random_state=397001220),
#  DecisionTreeRegressor(max_features='auto', random_state=1717523677),
#  DecisionTreeRegressor(max_features='auto', random_state=829414783),
#  DecisionTreeRegressor(max_features='auto', random_state=2111070750),
#  DecisionTreeRegressor(max_features='auto', random_state=345627191),
#  DecisionTreeRegressor(max_features='auto', random_state=1933692818),
#  DecisionTreeRegressor(max_features='auto', random_state=1917517385),
#  DecisionTreeRegressor(max_features='auto', random_state=1753147741),
#  DecisionTreeRegressor(max_features='auto', random_state=1052355604),
#  DecisionTreeRegressor(max_features='auto', random_state=1228759124),
#  DecisionTreeRegressor(max_features='auto', random_state=627928465),
#  DecisionTreeRegressor(max_features='auto', random_state=131770101),
#  DecisionTreeRegressor(max_features='auto', random_state=401604470),
#  DecisionTreeRegressor(max_features='auto', random_state=2100692381),
#  DecisionTreeRegressor(max_features='auto', random_state=791830428),
#  DecisionTreeRegressor(max_features='auto', random_state=1749165864),
#  DecisionTreeRegressor(max_features='auto', random_state=1598243508),
#  DecisionTreeRegressor(max_features='auto', random_state=1838096946),
#  DecisionTreeRegressor(max_features='auto', random_state=772160143),
#  DecisionTreeRegressor(max_features='auto', random_state=1007776587),
#  DecisionTreeRegressor(max_features='auto', random_state=1765064465),
#  DecisionTreeRegressor(max_features='auto', random_state=1305720477),
#  DecisionTreeRegressor(max_features='auto', random_state=178496292),
#  DecisionTreeRegressor(max_features='auto', random_state=2104734342),
#  DecisionTreeRegressor(max_features='auto', random_state=1849854801),
#  DecisionTreeRegressor(max_features='auto', random_state=1887016733),
#  DecisionTreeRegressor(max_features='auto', random_state=1152023489),
#  DecisionTreeRegressor(max_features='auto', random_state=1847253948),
#  DecisionTreeRegressor(max_features='auto', random_state=1262872799),
#  DecisionTreeRegressor(max_features='auto', random_state=1533596190),
#  DecisionTreeRegressor(max_features='auto', random_state=1661322300),
#  DecisionTreeRegressor(max_features='auto', random_state=1912627626),
#  DecisionTreeRegressor(max_features='auto', random_state=1185286572),
#  DecisionTreeRegressor(max_features='auto', random_state=1100928884),
#  DecisionTreeRegressor(max_features='auto', random_state=678503245),
#  DecisionTreeRegressor(max_features='auto', random_state=1482909409),
#  DecisionTreeRegressor(max_features='auto', random_state=1229436640),
#  DecisionTreeRegressor(max_features='auto', random_state=1630378996),
#  DecisionTreeRegressor(max_features='auto', random_state=19255790),
#  DecisionTreeRegressor(max_features='auto', random_state=1668595435),
#  DecisionTreeRegressor(max_features='auto', random_state=1573066073),
#  DecisionTreeRegressor(max_features='auto', random_state=80255773),
#  DecisionTreeRegressor(max_features='auto', random_state=945742240),
#  DecisionTreeRegressor(max_features='auto', random_state=1153343983),
#  DecisionTreeRegressor(max_features='auto', random_state=761053053),
#  DecisionTreeRegressor(max_features='auto', random_state=369452932)]

# %%
Dtree_model2.criterion
# Out:
# 'mse'

# %%
Dtree_model3 = DecisionTreeRegressor(criterion='mae').fit(xtrain2,ytrain2)
Dtree_model3.score(xtest2,ytest2)*100
# Out:
# 82.518355644946

# %%
scores = []
for i in range(10,250, 10):
    Rforest_model3 = RandomForestRegressor(n_estimators=i,).fit(xtrain2, ytrain2)
    scores.append(round(Rforest_model3.score(xtest2, ytest2)*100,2))

# %%
scores
# Out:
# [89.49,
#  89.44,
#  90.18,
#  90.29,
#  90.0,
#  90.02,
#  90.12,
#  90.18,
#  90.43,
#  90.3,
#  90.48,
#  90.31,
#  90.35,
#  90.55,
#  90.13,
#  90.29,
#  90.29,
#  90.4,
#  90.4,
#  90.4,
#  90.49,
#  90.35,
#  90.31,
#  90.28]

# %%
plt.figure(figsize=(12,7))
plt.plot(range(10,250, 10),scores,lw=3,marker='*',markersize=10,markerfacecolor='r',markeredgecolor='r')
plt.grid()
plt.ylim([80,100])
plt.yticks(range(80,100, 1))
plt.xticks(range(10,250, 10))
0
# Out:
# 0

# %%
from sklearn.model_selection import GridSearchCV

# %%
criterions = ['mse','mae']
# n_est = 
min_split = [4,6,8,10,14,18,20]

params = {'criterion':criterions,'min_samples_split':min_split}

# %%
dt_g_model = GridSearchCV(DecisionTreeRegressor(),param_grid=params,verbose=3)
dt_g_model.fit(xtrain2,ytrain2)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] criterion=mse, min_samples_split=4 ..............................
# [CV] .. criterion=mse, min_samples_split=4, score=0.850, total=   0.1s
# [CV] criterion=mse, min_samples_split=4 ..............................
# [CV] .. criterion=mse, min_samples_split=4, score=0.842, total=   0.1s
# [CV] criterion=mse, min_samples_split=4 ..............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] .. criterion=mse, min_samples_split=4, score=0.806, total=   0.1s
# [CV] criterion=mse, min_samples_split=4 ..............................
# [CV] .. criterion=mse, min_samples_split=4, score=0.757, total=   0.1s
# [CV] criterion=mse, min_samples_split=4 ..............................
# [CV] .. criterion=mse, min_samples_split=4, score=0.719, total=   0.1s
# [CV] criterion=mse, min_samples_split=6 ..............................
# [CV] .. criterion=mse, min_samples_split=6, score=0.844, total=   0.1s
# [CV] criterion=mse, min_samples_split=6 ..............................
# [CV] .. criterion=mse, min_samples_split=6, score=0.834, total=   0.0s
# [CV] criterion=mse, min_samples_split=6 ..............................
# [CV] .. criterion=mse, min_samples_split=6, score=0.814, total=   0.0s
# [CV] criterion=mse, min_samples_split=6 ..............................
# [CV] .. criterion=mse, min_samples_split=6, score=0.754, total=   0.1s
# [CV] criterion=mse, min_samples_split=6 ..............................
# [CV] .. criterion=mse, min_samples_split=6, score=0.777, total=   0.0s
# [CV] criterion=mse, min_samples_split=8 ..............................
# [CV] .. criterion=mse, min_samples_split=8, score=0.838, total=   0.0s
# [CV] criterion=mse, min_samples_split=8 ..............................
# [CV] .. criterion=mse, min_samples_split=8, score=0.848, total=   0.1s
# [CV] criterion=mse, min_samples_split=8 ..............................
# [CV] .. criterion=mse, min_samples_split=8, score=0.819, total=   0.0s
# [CV] criterion=mse, min_samples_split=8 ..............................
# [CV] .. criterion=mse, min_samples_split=8, score=0.771, total=   0.0s
# [CV] criterion=mse, min_samples_split=8 ..............................
# [CV] .. criterion=mse, min_samples_split=8, score=0.777, total=   0.0s
# [CV] criterion=mse, min_samples_split=10 .............................
# [CV] . criterion=mse, min_samples_split=10, score=0.838, total=   0.0s
# [CV] criterion=mse, min_samples_split=10 .............................
# [CV] . criterion=mse, min_samples_split=10, score=0.846, total=   0.0s
# [CV] criterion=mse, min_samples_split=10 .............................
# [CV] . criterion=mse, min_samples_split=10, score=0.824, total=   0.0s
# [CV] criterion=mse, min_samples_split=10 .............................
# [CV] . criterion=mse, min_samples_split=10, score=0.762, total=   0.0s
# [CV] criterion=mse, min_samples_split=10 .............................
# [CV] . criterion=mse, min_samples_split=10, score=0.778, total=   0.0s
# [CV] criterion=mse, min_samples_split=14 .............................
# [CV] . criterion=mse, min_samples_split=14, score=0.840, total=   0.0s
# [CV] criterion=mse, min_samples_split=14 .............................
# [CV] . criterion=mse, min_samples_split=14, score=0.854, total=   0.0s
# [CV] criterion=mse, min_samples_split=14 .............................
# [CV] . criterion=mse, min_samples_split=14, score=0.820, total=   0.0s
# [CV] criterion=mse, min_samples_split=14 .............................
# [CV] . criterion=mse, min_samples_split=14, score=0.840, total=   0.0s
# [CV] criterion=mse, min_samples_split=14 .............................
# [CV] . criterion=mse, min_samples_split=14, score=0.789, total=   0.0s
# [CV] criterion=mse, min_samples_split=18 .............................
# [CV] . criterion=mse, min_samples_split=18, score=0.832, total=   0.0s
# [CV] criterion=mse, min_samples_split=18 .............................
# [CV] . criterion=mse, min_samples_split=18, score=0.850, total=   0.0s
# [CV] criterion=mse, min_samples_split=18 .............................
# [CV] . criterion=mse, min_samples_split=18, score=0.821, total=   0.0s
# [CV] criterion=mse, min_samples_split=18 .............................
# [CV] . criterion=mse, min_samples_split=18, score=0.847, total=   0.0s
# [CV] criterion=mse, min_samples_split=18 .............................
# [CV] . criterion=mse, min_samples_split=18, score=0.791, total=   0.0s
# [CV] criterion=mse, min_samples_split=20 .............................
# [CV] . criterion=mse, min_samples_split=20, score=0.827, total=   0.0s
# [CV] criterion=mse, min_samples_split=20 .............................
# [CV] . criterion=mse, min_samples_split=20, score=0.850, total=   0.0s
# [CV] criterion=mse, min_samples_split=20 .............................
# [CV] . criterion=mse, min_samples_split=20, score=0.822, total=   0.0s
# [CV] criterion=mse, min_samples_split=20 .............................
# [CV] . criterion=mse, min_samples_split=20, score=0.847, total=   0.0s
# [CV] criterion=mse, min_samples_split=20 .............................
# [CV] . criterion=mse, min_samples_split=20, score=0.789, total=   0.0s
# [CV] criterion=mae, min_samples_split=4 ..............................
# [CV] .. criterion=mae, min_samples_split=4, score=0.785, total=   2.3s
# [CV] criterion=mae, min_samples_split=4 ..............................
# [CV] .. criterion=mae, min_samples_split=4, score=0.824, total=   2.3s
# [CV] criterion=mae, min_samples_split=4 ..............................
# [CV] .. criterion=mae, min_samples_split=4, score=0.757, total=   2.1s
# [CV] criterion=mae, min_samples_split=4 ..............................
# [CV] .. criterion=mae, min_samples_split=4, score=0.763, total=   2.2s
# [CV] criterion=mae, min_samples_split=4 ..............................
# [CV] .. criterion=mae, min_samples_split=4, score=0.782, total=   2.3s
# [CV] criterion=mae, min_samples_split=6 ..............................
# [CV] .. criterion=mae, min_samples_split=6, score=0.791, total=   2.2s
# [CV] criterion=mae, min_samples_split=6 ..............................
# [CV] .. criterion=mae, min_samples_split=6, score=0.822, total=   2.3s
# [CV] criterion=mae, min_samples_split=6 ..............................
# [CV] .. criterion=mae, min_samples_split=6, score=0.784, total=   2.1s
# [CV] criterion=mae, min_samples_split=6 ..............................
# [CV] .. criterion=mae, min_samples_split=6, score=0.749, total=   2.6s
# [CV] criterion=mae, min_samples_split=6 ..............................
# [CV] .. criterion=mae, min_samples_split=6, score=0.777, total=   2.3s
# [CV] criterion=mae, min_samples_split=8 ..............................
# [CV] .. criterion=mae, min_samples_split=8, score=0.803, total=   2.3s
# [CV] criterion=mae, min_samples_split=8 ..............................
# [CV] .. criterion=mae, min_samples_split=8, score=0.826, total=   2.2s
# [CV] criterion=mae, min_samples_split=8 ..............................
# [CV] .. criterion=mae, min_samples_split=8, score=0.780, total=   2.1s
# [CV] criterion=mae, min_samples_split=8 ..............................
# [CV] .. criterion=mae, min_samples_split=8, score=0.751, total=   2.1s
# [CV] criterion=mae, min_samples_split=8 ..............................
# [CV] .. criterion=mae, min_samples_split=8, score=0.779, total=   2.2s
# [CV] criterion=mae, min_samples_split=10 .............................
# [CV] . criterion=mae, min_samples_split=10, score=0.828, total=   2.2s
# [CV] criterion=mae, min_samples_split=10 .............................
# [CV] . criterion=mae, min_samples_split=10, score=0.821, total=   2.4s
# [CV] criterion=mae, min_samples_split=10 .............................
# [CV] . criterion=mae, min_samples_split=10, score=0.778, total=   2.1s
# [CV] criterion=mae, min_samples_split=10 .............................
# [CV] . criterion=mae, min_samples_split=10, score=0.759, total=   2.0s
# [CV] criterion=mae, min_samples_split=10 .............................
# [CV] . criterion=mae, min_samples_split=10, score=0.784, total=   2.5s
# [CV] criterion=mae, min_samples_split=14 .............................
# [CV] . criterion=mae, min_samples_split=14, score=0.822, total=   2.2s
# [CV] criterion=mae, min_samples_split=14 .............................
# [CV] . criterion=mae, min_samples_split=14, score=0.829, total=   2.9s
# [CV] criterion=mae, min_samples_split=14 .............................
# [CV] . criterion=mae, min_samples_split=14, score=0.772, total=   3.3s
# [CV] criterion=mae, min_samples_split=14 .............................
# [CV] . criterion=mae, min_samples_split=14, score=0.822, total=   2.5s
# [CV] criterion=mae, min_samples_split=14 .............................
# [CV] . criterion=mae, min_samples_split=14, score=0.785, total=   2.3s
# [CV] criterion=mae, min_samples_split=18 .............................
# [CV] . criterion=mae, min_samples_split=18, score=0.825, total=   2.2s
# [CV] criterion=mae, min_samples_split=18 .............................
# [CV] . criterion=mae, min_samples_split=18, score=0.828, total=   2.2s
# [CV] criterion=mae, min_samples_split=18 .............................
# [CV] . criterion=mae, min_samples_split=18, score=0.773, total=   2.1s
# [CV] criterion=mae, min_samples_split=18 .............................
# [CV] . criterion=mae, min_samples_split=18, score=0.814, total=   2.1s
# [CV] criterion=mae, min_samples_split=18 .............................
# [CV] . criterion=mae, min_samples_split=18, score=0.787, total=   2.3s
# [CV] criterion=mae, min_samples_split=20 .............................
# [CV] . criterion=mae, min_samples_split=20, score=0.822, total=   2.2s
# [CV] criterion=mae, min_samples_split=20 .............................
# [CV] . criterion=mae, min_samples_split=20, score=0.828, total=   2.4s
# [CV] criterion=mae, min_samples_split=20 .............................
# [CV] . criterion=mae, min_samples_split=20, score=0.769, total=   2.1s
# [CV] criterion=mae, min_samples_split=20 .............................
# [CV] . criterion=mae, min_samples_split=20, score=0.817, total=   2.2s
# [CV] criterion=mae, min_samples_split=20 .............................
# [CV] . criterion=mae, min_samples_split=20, score=0.785, total=   2.3s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  1.4min finished
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'min_samples_split': [4, 6, 8, 10, 14, 18, 20]},
#              verbose=3)

# %%
dt_g_model.best_estimator_
# Out:
# DecisionTreeRegressor(min_samples_split=14)

# %%
dt_g_model.best_params_
# Out:
# {'criterion': 'mse', 'min_samples_split': 14}

# %%
dt_g_model.best_estimator_.score(xtest2,ytest2)
# Out:
# 0.8640381524529093

# %%
Dtree_model_best_view = DecisionTreeRegressor(criterion= 'mse', min_samples_split = 18,random_state=101).fit(xtrain2,ytrain2)
Dtree_model_best_view.score(xtest2,ytest2)*100
# Out:
# 85.85090027801927

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
criterions = ['mse','mae']
n_est = list(range(10,201,10))
min_split = [2, 5, 10, 15, 100]
# best_feature = ['sqrt','auto']
params = {'criterion' : criterions,'n_estimators':n_est,'min_samples_split':min_split}

# %%
rf_g_model= RandomizedSearchCV(RandomForestRegressor(),param_distributions=params,verbose=5)

# %%
rf_g_model.fit(xtrain2,ytrain2)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=140, min_samples_split=2, criterion=mae ............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=140, min_samples_split=2, criterion=mae, score=0.859, total= 2.3min
# [CV] n_estimators=140, min_samples_split=2, criterion=mae ............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [CV]  n_estimators=140, min_samples_split=2, criterion=mae, score=0.887, total= 2.3min
# [CV] n_estimators=140, min_samples_split=2, criterion=mae ............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.7min remaining:    0.0s
# [CV]  n_estimators=140, min_samples_split=2, criterion=mae, score=0.852, total= 2.3min
# [CV] n_estimators=140, min_samples_split=2, criterion=mae ............
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  7.0min remaining:    0.0s
# [CV]  n_estimators=140, min_samples_split=2, criterion=mae, score=0.883, total= 2.4min
# [CV] n_estimators=140, min_samples_split=2, criterion=mae ............
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  9.4min remaining:    0.0s
# [CV]  n_estimators=140, min_samples_split=2, criterion=mae, score=0.845, total= 2.3min
# [CV] n_estimators=40, min_samples_split=10, criterion=mae ............
# [CV]  n_estimators=40, min_samples_split=10, criterion=mae, score=0.856, total=  39.1s
# [CV] n_estimators=40, min_samples_split=10, criterion=mae ............
# [CV]  n_estimators=40, min_samples_split=10, criterion=mae, score=0.876, total=  40.9s
# [CV] n_estimators=40, min_samples_split=10, criterion=mae ............
# [CV]  n_estimators=40, min_samples_split=10, criterion=mae, score=0.833, total=  37.9s
# [CV] n_estimators=40, min_samples_split=10, criterion=mae ............
# [CV]  n_estimators=40, min_samples_split=10, criterion=mae, score=0.850, total=  38.3s
# [CV] n_estimators=40, min_samples_split=10, criterion=mae ............
# [CV]  n_estimators=40, min_samples_split=10, criterion=mae, score=0.817, total=  39.3s
# [CV] n_estimators=40, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=40, min_samples_split=5, criterion=mae, score=0.861, total=  39.7s
# [CV] n_estimators=40, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=40, min_samples_split=5, criterion=mae, score=0.884, total=  39.2s
# [CV] n_estimators=40, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=40, min_samples_split=5, criterion=mae, score=0.848, total=  39.4s
# [CV] n_estimators=40, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=40, min_samples_split=5, criterion=mae, score=0.873, total=  38.1s
# [CV] n_estimators=40, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=40, min_samples_split=5, criterion=mae, score=0.842, total=  38.3s
# [CV] n_estimators=20, min_samples_split=5, criterion=mse .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mse, score=0.854, total=   0.6s
# [CV] n_estimators=20, min_samples_split=5, criterion=mse .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mse, score=0.883, total=   0.6s
# [CV] n_estimators=20, min_samples_split=5, criterion=mse .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mse, score=0.854, total=   0.6s
# [CV] n_estimators=20, min_samples_split=5, criterion=mse .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mse, score=0.892, total=   0.5s
# [CV] n_estimators=20, min_samples_split=5, criterion=mse .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mse, score=0.833, total=   0.6s
# [CV] n_estimators=20, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mae, score=0.853, total=  19.4s
# [CV] n_estimators=20, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mae, score=0.875, total=  20.0s
# [CV] n_estimators=20, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mae, score=0.847, total=  19.1s
# [CV] n_estimators=20, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mae, score=0.871, total=  19.4s
# [CV] n_estimators=20, min_samples_split=5, criterion=mae .............
# [CV]  n_estimators=20, min_samples_split=5, criterion=mae, score=0.829, total=  19.4s
# [CV] n_estimators=160, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=160, min_samples_split=2, criterion=mae, score=0.853, total= 2.8min
# [CV] n_estimators=160, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=160, min_samples_split=2, criterion=mae, score=0.888, total= 2.7min
# [CV] n_estimators=160, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=160, min_samples_split=2, criterion=mae, score=0.852, total= 2.7min
# [CV] n_estimators=160, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=160, min_samples_split=2, criterion=mae, score=0.885, total= 2.7min
# [CV] n_estimators=160, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=160, min_samples_split=2, criterion=mae, score=0.841, total= 2.8min
# [CV] n_estimators=170, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=170, min_samples_split=2, criterion=mae, score=0.857, total= 2.8min
# [CV] n_estimators=170, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=170, min_samples_split=2, criterion=mae, score=0.890, total= 2.8min
# [CV] n_estimators=170, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=170, min_samples_split=2, criterion=mae, score=0.852, total= 2.8min
# [CV] n_estimators=170, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=170, min_samples_split=2, criterion=mae, score=0.883, total= 2.8min
# [CV] n_estimators=170, min_samples_split=2, criterion=mae ............
# [CV]  n_estimators=170, min_samples_split=2, criterion=mae, score=0.838, total= 2.8min
# [CV] n_estimators=100, min_samples_split=5, criterion=mae ............
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-6ba598d36305> in <module>
# ----> 1 rf_g_model.fit(xtrain2,ytrain2)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1527     def _run_search(self, evaluate_candidates):
#    1528         """Search n_iter candidates from param_distributions"""
# -> 1529         evaluate_candidates(ParameterSampler(
#    1530             self.param_distributions, self.n_iter,
#    1531             random_state=self.random_state))
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
rf_g_model.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-4dbc2719c10d> in <module>
# ----> 1 rf_g_model.best_params_
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_params_'

# %%
rf_g_model.best_params_

# %%
rf_g_model_best_view =RandomForestRegressor(n_estimators= 140, min_samples_split= 5, criterion= 'mse').fit(xtrain2,ytrain2)

# %%
rf_g_model_best_view.score(xtest2,ytest2)*100
# Out:
# 90.0085369111029

# %%
final_model=rf_g_model

# %%
pd.to_pickle(final_model,'FlightPricePredictor')
