# %%
import pandas as pd
import numpy as np

# %%
data= np.loadtxt('country_wise_latest.csv',delimiter=',',dtype=str)
data
# Out:
# array([['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#         'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#         'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#         'Confirmed last week', '1 week change', '1 week % increase',
#         'WHO Region'],
#        ['Afghanistan', '36263', '1269', '25198', '9796', '106', '10',
#         '18', '3.5', '69.49', '5.04', '35526', '737', '2.07',
#         'Eastern Mediterranean'],
#        ['Albania', '4880', '144', '2745', '1991', '117', '6', '63',
#         '2.95', '56.25', '5.25', '4171', '709', '17', 'Europe'],
#        ['Algeria', '27973', '1163', '18837', '7973', '616', '8', '749',
#         '4.16', '67.34', '6.17', '23691', '4282', '18.07', 'Africa'],
#        ['Andorra', '907', '52', '803', '52', '10', '0', '0', '5.73',
#         '88.53', '6.48', '884', '23', '2.6', 'Europe'],
#        ['Angola', '950', '41', '242', '667', '18', '1', '0', '4.32',
# ...

# %%
df=pd.read_csv('covid_info.csv')

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
ds=pd.read_csv('supermarkets-semi-colons.txt',delimiter=";")

# %%
#Adding Headings
cols='ID Address City State Country Name Employees'.split()
pd.read_csv('supermarkets-nohead.txt',names=cols)
# Out:
#               ID          Address           City             State Country  \
# 0              1     3666 21st St  San Francisco          CA 94114     USA
# 1              2   735 Dolores St  San Francisco          CA 94119     USA
# 2              3      332 Hill St  San Francisco  California 94114     USA
# 3              4     3995 23rd St  San Francisco          CA 94114     USA
# 4              5  1056 Sanchez St  San Francisco        California     USA
# 5              6  551 Alvarado St  San Francisco          CA 94114     USA
# 6  © 2021 GitHub             Inc.            NaN               NaN     NaN
#
#           Name  Employees
# 0      Madeira        8.0
# 1  Bready Shop       15.0
# 2  Super River       25.0
# 3   Ben's Shop       10.0
# 4      Sanchez       12.0
# 5   Richvalley       20.0
# 6          NaN        NaN

# %%
#for making ID column as index column
cols=' Address City State Country Name Employees'.split()
pd.read_csv('supermarkets-nohead.txt',names=cols,index_col=0)
# Out:
#                        Address           City             State Country  \
# 1                 3666 21st St  San Francisco          CA 94114     USA
# 2               735 Dolores St  San Francisco          CA 94119     USA
# 3                  332 Hill St  San Francisco  California 94114     USA
# 4                 3995 23rd St  San Francisco          CA 94114     USA
# 5              1056 Sanchez St  San Francisco        California     USA
# 6              551 Alvarado St  San Francisco          CA 94114     USA
# © 2021 GitHub             Inc.            NaN               NaN     NaN
#
#                       Name  Employees
# 1                  Madeira        8.0
# 2              Bready Shop       15.0
# 3              Super River       25.0
# 4               Ben's Shop       10.0
# 5                  Sanchez       12.0
# 6               Richvalley       20.0
# © 2021 GitHub          NaN        NaN

# %%
#used fro pasting what is saved in clipboard
df2=pd.read_clipboard()
df2
# Out:
# Empty DataFrame
# Columns: [D:\AI, summer, training]
# Index: []

# %%
#Logical Indexing

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df['Active']>=1000
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# Name: Active, dtype: bool

# %%
df[df['Active']>=1000]       #for finding values of corroespondig index
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# ...

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df['Population']=pd.Series([2000000,4000000,50000000,30000000,280000000,197000000],index=range(0,6))
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df[(df['Confirmed']>=5000) & (df['Deaths']>500)]        #we use bitwise opr here as logical opr doenit work here
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 2        Algeria      27973    1163      18837    7973        616           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 2            749                4.16                  67.34
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 2                    6.17                23691           4282
#
#    1 week % increase             WHO Region  Population
# 0               2.07  Eastern Mediterranean     2000000
# 2              18.07                 Africa    50000000

# %%
df['Recovered'][df['Active']>=1000].mean()
# Out:
# 15593.333333333334

# %% [markdown]
# ### Pandas Functionalites

# %% [markdown]
# #### 1.Attribuutes

# %%
s=pd.Series([4,5,7,8,2,3,4,5])

# %%
s
# Out:
# 0    4
# 1    5
# 2    7
# 3    8
# 4    2
# 5    3
# 6    4
# 7    5
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.empty
# Out:
# False

# %%
s.ndim
# Out:
# 1

# %%
df.size
# Out:
# 96

# %%
s.values        #for conversion in array
# Out:
# array([4, 5, 7, 8, 2, 3, 4, 5], dtype=int64)

# %%
df.values
# Out:
# array([['Afghanistan', 36263, 1269, 25198, 9796, 106, 10, 18, 3.5, 69.49,
#         5.04, 35526, 737, 2.07, 'Eastern Mediterranean', 2000000],
#        ['Albania', 4880, 144, 2745, 1991, 117, 6, 63, 2.95, 56.25, 5.25,
#         4171, 709, 17.0, 'Europe', 4000000],
#        ['Algeria', 27973, 1163, 18837, 7973, 616, 8, 749, 4.16, 67.34,
#         6.17, 23691, 4282, 18.07, 'Africa', 50000000],
#        ['Andorra', 907, 52, 803, 52, 10, 0, 0, 5.73, 88.53, 6.48, 884,
#         23, 2.6, 'Europe', 30000000],
#        ['Angola', 950, 41, 242, 667, 18, 1, 0, 4.32, 25.47, 16.94, 749,
#         201, 26.84, 'Africa', 280000000],
#        ['Antigua and Barbuda', 86, 3, 65, 18, 4, 0, 5, 3.49, 75.58, 4.62,
#         76, 10, 13.16, 'Americas', 197000000]], dtype=object)

# %%
df.T
# Out:
#                                             0        1         2         3  \
# Country/Region                    Afghanistan  Albania   Algeria   Andorra
# Confirmed                               36263     4880     27973       907
# Deaths                                   1269      144      1163        52
# Recovered                               25198     2745     18837       803
# Active                                   9796     1991      7973        52
# New cases                                 106      117       616        10
# New deaths                                 10        6         8         0
# New recovered                              18       63       749         0
# Deaths / 100 Cases                        3.5     2.95      4.16      5.73
# Recovered / 100 Cases                   69.49    56.25     67.34     88.53
# Deaths / 100 Recovered                   5.04     5.25      6.17      6.48
# ...

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df.axes            #shows rows and columns
# Out:
# [RangeIndex(start=0, stop=6, step=1),
#  Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#         'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#         'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#         'Confirmed last week', '1 week change', '1 week % increase',
#         'WHO Region', 'Population'],
#        dtype='object')]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region', 'Population'],
#       dtype='object')

# %%
df.columns[:-2]
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase'],
#       dtype='object')

# %% [markdown]
# ### 2.Statistical Views

# %%
s.sum()
# Out:
# 38

# %%
s.mean()
# Out:
# 4.75

# %%
s.max()
# Out:
# 8

# %%
s.idxmax()        #it shows where ismax values
# Out:
# 3

# %%
df.sum()
# Out:
# Country/Region            AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# Confirmed                                                             71059
# Deaths                                                                 2672
# Recovered                                                             47890
# Active                                                                20497
# New cases                                                               871
# New deaths                                                               25
# New recovered                                                           835
# Deaths / 100 Cases                                                    24.15
# Recovered / 100 Cases                                                382.66
# Deaths / 100 Recovered                                                 44.5
# Confirmed last week                                                   65097
# ...

# %%
df[['Active','Deaths']].mean()
# Out:
# Active    3416.166667
# Deaths     445.333333
# dtype: float64

# %%
df.std()
# Out:
# Confirmed                 1.600923e+04
# Deaths                    5.996881e+02
# Recovered                 1.109750e+04
# Active                    4.334078e+03
# New cases                 2.359580e+02
# New deaths                4.400758e+00
# New recovered             2.997048e+02
# Deaths / 100 Cases        9.725996e-01
# Recovered / 100 Cases     2.154733e+01
# Deaths / 100 Recovered    4.717833e+00
# Confirmed last week       1.507207e+04
# 1 week change             1.643056e+03
# 1 week % increase         9.595795e+00
# Population                1.164481e+08
# dtype: float64

# %%
df.min()
# Out:
# Country/Region            Afghanistan
# Confirmed                          86
# Deaths                              3
# Recovered                          65
# Active                             18
# New cases                           4
# New deaths                          0
# New recovered                       0
# Deaths / 100 Cases               2.95
# Recovered / 100 Cases           25.47
# Deaths / 100 Recovered           4.62
# Confirmed last week                76
# 1 week change                      10
# 1 week % increase                2.07
# WHO Region                     Africa
# Population                    2000000
# dtype: object

# %%
df['Active'].min()
# Out:
# 18

# %%
dd=df[['Active','Deaths']]
dd
# Out:
#    Active  Deaths
# 0    9796    1269
# 1    1991     144
# 2    7973    1163
# 3      52      52
# 4     667      41
# 5      18       3

# %%
dd.sum(axis=0)
# Out:
# Active    20497
# Deaths     2672
# dtype: int64

# %%
dd.sum(axis=1)
# Out:
# 0    11065
# 1     2135
# 2     9136
# 3      104
# 4      708
# 5       21
# dtype: int64

# %%
dd.count()
# Out:
# Active    6
# Deaths    6
# dtype: int64

# %%
dd.sort_values('Deaths')
# Out:
#    Active  Deaths
# 5      18       3
# 4     667      41
# 3      52      52
# 1    1991     144
# 2    7973    1163
# 0    9796    1269

# %%
dd.sort_index()
# Out:
#    Active  Deaths
# 0    9796    1269
# 1    1991     144
# 2    7973    1163
# 3      52      52
# 4     667      41
# 5      18       3

# %%
dd[dd['Active']>=1000].count()
# Out:
# Active    3
# Deaths    3
# dtype: int64

# %%
dd.describe()
# Out:
#             Active       Deaths
# count     6.000000     6.000000
# mean   3416.166667   445.333333
# std    4334.078330   599.688141
# min      18.000000     3.000000
# 25%     205.750000    43.750000
# 50%    1329.000000    98.000000
# 75%    6477.500000   908.250000
# max    9796.000000  1269.000000

# %%
dd[dd.columns[:-1]].describe()
# Out:
#             Active
# count     6.000000
# mean   3416.166667
# std    4334.078330
# min      18.000000
# 25%     205.750000
# 50%    1329.000000
# 75%    6477.500000
# max    9796.000000

# %%
d=df.describe(include='all')

# %%
d
# Out:
#        Country/Region     Confirmed       Deaths     Recovered       Active  \
# count               6      6.000000     6.000000      6.000000     6.000000
# unique              6           NaN          NaN           NaN          NaN
# top           Albania           NaN          NaN           NaN          NaN
# freq                1           NaN          NaN           NaN          NaN
# mean              NaN  11843.166667   445.333333   7981.666667  3416.166667
# std               NaN  16009.230230   599.688141  11097.498631  4334.078330
# min               NaN     86.000000     3.000000     65.000000    18.000000
# 25%               NaN    917.750000    43.750000    382.250000   205.750000
# 50%               NaN   2915.000000    98.000000   1774.000000  1329.000000
# 75%               NaN  22199.750000   908.250000  14814.000000  6477.500000
# max               NaN  36263.000000  1269.000000  25198.000000  9796.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          6 non-null      object
#  1   Confirmed               6 non-null      int64
#  2   Deaths                  6 non-null      int64
#  3   Recovered               6 non-null      int64
#  4   Active                  6 non-null      int64
#  5   New cases               6 non-null      int64
#  6   New deaths              6 non-null      int64
#  7   New recovered           6 non-null      int64
#  8   Deaths / 100 Cases      6 non-null      float64
#  9   Recovered / 100 Cases   6 non-null      float64
#  10  Deaths / 100 Recovered  6 non-null      float64
#  11  Confirmed last week     6 non-null      int64
#  12  1 week change           6 non-null      int64
#  13  1 week % increase       6 non-null      float64
# ...

# %% [markdown]
# #### 3.Working  on String Data

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
country=df['Country/Region']
country
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                Andorra
# 4                 Angola
# 5    Antigua and Barbuda
# Name: Country/Region, dtype: object

# %%
country.str.lower()
# Out:
# 0            afghanistan
# 1                albania
# 2                algeria
# 3                andorra
# 4                 angola
# 5    antigua and barbuda
# Name: Country/Region, dtype: object

# %%
country.str.upper()
# Out:
# 0            AFGHANISTAN
# 1                ALBANIA
# 2                ALGERIA
# 3                ANDORRA
# 4                 ANGOLA
# 5    ANTIGUA AND BARBUDA
# Name: Country/Region, dtype: object

# %%
country.str.capitalize()
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                Andorra
# 4                 Angola
# 5    Antigua and barbuda
# Name: Country/Region, dtype: object

# %%
country.str.len()
# Out:
# 0    11
# 1     7
# 2     7
# 3     7
# 4     6
# 5    19
# Name: Country/Region, dtype: int64

# %%
len(country)
# Out:
# 6

# %%
country.str.split()
# Out:
# 0              [Afghanistan]
# 1                  [Albania]
# 2                  [Algeria]
# 3                  [Andorra]
# 4                   [Angola]
# 5    [Antigua, and, Barbuda]
# Name: Country/Region, dtype: object

# %%
country.str.cat(sep='&&')
# Out:
# 'Afghanistan&&Albania&&Algeria&&Andorra&&Angola&&Antigua and Barbuda'

# %%
country.str.contains('z')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Country/Region, dtype: bool

# %%
'a' in df['Country/Region']
# Out:
# False

# %%
# replace
# repeat
# count
# find
# startswith
# isupper
# isnumeric
#....

# %%
ds
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [raw]
# # Create a new column that should have initials of shop name
# #ds['initials'] = pd.Series(map(lambda x: ''.join([i[0] for i in x]),ds['Name'].str.split(' ')), index=range(1,7))
# #ds

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df['Inits']=pd.Series(map(lambda x :' '.join(i[0:2] for i in x ),df['Country/Region'].str.split(' ')))
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# 4           1              0                4.32                  25.47
# ...

# %%
df['New positives']=df['New cases']

# %%
del df['New cases']

# %%
df
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New deaths  \
# 0          Afghanistan      36263    1269      25198    9796          10
# 1              Albania       4880     144       2745    1991           6
# 2              Algeria      27973    1163      18837    7973           8
# 3              Andorra        907      52        803      52           0
# 4               Angola        950      41        242     667           1
# 5  Antigua and Barbuda         86       3         65      18           0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
# 5              5                3.49                  75.58
#
# ...

# %%
ds
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20
