# %%
# Color Spaces
# Cropping
# Resize
# Rotation
# Brightness
# Contrast
# Image Thresholding
# Morphology
# Live Images

# %%
from skimage import io,exposure ,color, transform
import cv2
import matplotlib.pyplot as plt
import face_recognition

# %%
img = cv2.imread('CRISTIANO-RONALDO.jpg')

# %%
def imshow(im):
    cv2.imshow('image',im)
    cv2.waitKey(0)

# %%
def showimg(im):
    io.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))

# %%
imshow(img)

# %%
img_a = cv2.convertScaleAbs(img, alpha=1, beta=80) # brightness (beta) 0-100, contrast (alpha) 1.0 to 3.0

# %%
showimg(img)

# %%
img.shape
# Out:
# (749, 1200, 3)

# %%
showimg(img_a)

# %%
img_b = cv2.convertScaleAbs(img, alpha=1.5, beta=1)
showimg(img_b)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img_red_ = img[:,:,-1].copy()
img_green_ = img[:,:,-2].copy()
img_blue_ = img[:,:,-3].copy()

# %%
showimg(img_gray)

# %%
plt.figure(figsize=(25,10))
plt.subplot(2,3,1)
showimg(img_red_)
plt.subplot(2,3,2)
showimg(img_green_)
plt.subplot(2,3,3)
showimg(img_blue_)
plt.subplot(2,3,4)
showimg(img_gray)
plt.subplot(2,3,5)
showimg(img)

# %%
img_red = cv2.subtract(img_red_, img_gray)

# %%
showimg(img_red)

# %%
def view_img(im, convert=True):
    if convert:
        v = viewer.ImageViewer(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
    else:
        v = viewer.ImageViewer(im)    
    v.show()

# %%
view_img(img_red)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-74cb73dbfa26> in <module>
# ----> 1 view_img(img_red)
#
# <ipython-input-22-4691192a9782> in view_img(im, convert)
#       1 def view_img(im, convert=True):
#       2     if convert:
# ----> 3         v = viewer.ImageViewer(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
#       4     else:
#       5         v = viewer.ImageViewer(im)
#
# NameError: name 'viewer' is not defined

# %%
rows ,columns , plane = img.shape
img_copy = img.copy()
for r in range(rows):
    for c in range(columns):
        img_copy[r,c,-1] = cv2.subtract(img_copy[r,c,-1],50)
        img_copy[r,c,-2] = cv2.add(img_copy[r,c,-2],80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-81ed767de8a6> in <module>
#       3 for r in range(rows):
#       4     for c in range(columns):
# ----> 5         img_copy[r,c,-1] = cv2.subtract(img_copy[r,c,-1],50)
#       6         img_copy[r,c,-2] = cv2.add(img_copy[r,c,-2],80)
#
# TypeError: Expected Ptr<cv::UMat> for argument 'src1'
