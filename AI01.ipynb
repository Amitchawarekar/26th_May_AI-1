# %%
import skimage
import cv2
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
import PIL as Image
import io
import skimage.io

# %%
img1 =ipd.Image('CRISTIANO-RONALDO.jpg')

# %%
img1

# %%
img2 = Image.open('messi.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9f40347b65ea> in <module>
# ----> 1 img2 = Image.open('messi.jpg')
#
# ~\anaconda3\lib\site-packages\PIL\__init__.py in __getattr__(name)
#      40             _raise_version_warning()
#      41             return __version__
# ---> 42         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#      43
#      44
#
# AttributeError: module 'PIL' has no attribute 'open'

# %%
img3=plt.imread('images.jpg')

# %%
img3
# Out:
# array([[[ 15,  18,  27],
#         [ 15,  18,  27],
#         [ 15,  18,  27],
#         ...,
#         [  8,  20,  34],
#         [  8,  20,  34],
#         [  8,  20,  34]],
#
#        [[ 15,  18,  27],
#         [ 15,  18,  27],
#         [ 15,  18,  27],
#         ...,
#         [  9,  18,  33],
#         [  9,  18,  33],
#         [  9,  18,  33]],
#
#        [[ 14,  17,  26],
#         [ 14,  17,  26],
#         [ 14,  17,  26],
#         ...,
#         [  8,  18,  30],
#         [  8,  18,  30],
#         [  8,  18,  30]],
#
#        ...,
#
#        [[162, 175, 191],
#         [162, 175, 191],
#         [162, 176, 189],
#         ...,
#         [ 19,  17,  18],
#         [ 19,  17,  18],
#         [ 19,  17,  18]],
#
#        [[156, 172, 188],
#         [156, 172, 187],
#         [156, 172, 187],
#         ...,
#         [ 19,  17,  18],
#         [ 19,  17,  18],
#         [ 19,  17,  18]],
#
#        [[153, 169, 185],
#         [153, 169, 185],
#         [153, 169, 184],
# ...

# %%
img3.shape
# Out:
# (168, 300, 3)

# %%
img3
# Out:
# array([[[ 15,  18,  27],
#         [ 15,  18,  27],
#         [ 15,  18,  27],
#         ...,
#         [  8,  20,  34],
#         [  8,  20,  34],
#         [  8,  20,  34]],
#
#        [[ 15,  18,  27],
#         [ 15,  18,  27],
#         [ 15,  18,  27],
#         ...,
#         [  9,  18,  33],
#         [  9,  18,  33],
#         [  9,  18,  33]],
#
#        [[ 14,  17,  26],
#         [ 14,  17,  26],
#         [ 14,  17,  26],
#         ...,
#         [  8,  18,  30],
#         [  8,  18,  30],
#         [  8,  18,  30]],
#
#        ...,
#
#        [[162, 175, 191],
#         [162, 175, 191],
#         [162, 176, 189],
#         ...,
#         [ 19,  17,  18],
#         [ 19,  17,  18],
#         [ 19,  17,  18]],
#
#        [[156, 172, 188],
#         [156, 172, 187],
#         [156, 172, 187],
#         ...,
#         [ 19,  17,  18],
#         [ 19,  17,  18],
#         [ 19,  17,  18]],
#
#        [[153, 169, 185],
#         [153, 169, 185],
#         [153, 169, 184],
# ...

# %%
plt.imshow(img3)

# %%
img3_1 = img3[:,:,0].copy()

# %%
img3_1.shape
# Out:
# (168, 300)

# %%
plt.imshow(img3_1)

# %%
plt.imsave('redmessi.jpg',img3_1,cmap='gray')

# %%
ipd.Image('redmessi.jpg')

# %%
plt.imshow(img3[:,:,1])

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)
plt.imshow(img3[:,:,0],cmap='gray')
plt.subplot(2,2,2)
plt.imshow(img3[:,:,1],cmap='gray')
plt.subplot(2,2,3)
plt.imshow(img3[:,:,2],cmap='gray')
plt.subplot(2,2,4)
plt.imshow(img3)

# %%
img4 = cv2.imread('images.jpg')

# %%
cv2.imshow('Image',img4)
cv2.waitKey(0)
# Out:
# -1

# %%
img4_red = img4[:,:,2] #red component

# %%
cv2.imwrite('red_messi_cv2.jpg',img4_red)
# Out:
# True

# %%
img5 = io.imread('messi.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0c0868c88d16> in <module>
# ----> 1 img5 = io.imread('messi.jpg')
#
# AttributeError: module 'io' has no attribute 'imread'

# %%
# Color Spaces
# Brightness
# Contrast
# Cropping
# Rotation
# Resize
# Image Thresholding
